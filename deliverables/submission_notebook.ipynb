# %% [markdown]
# # Notebook de soumission — Projet Deep Learning
#
# Ce notebook exécute les trois parties du projet (MLP, CNN, RNN/Seq2Seq) et collecte les livrables dans `deliverables/`.
#
# **Prérequis** : exécuter depuis la racine du projet après `pip install -r requirements.txt`.

# %%
import sys
from pathlib import Path

ROOT = Path('..').resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
print('Project root:', ROOT)

# %%
from part1_mlp.validate_checklist import run as run_part1
from part2_cnn.validate_checklist import run as run_part2
from part3_rnn.validate_checklist import run as run_part3

print('Part 1:', run_part1())

# %%
print('Part 2:', run_part2())

# %%
print('Part 3:', run_part3())

# %%
import subprocess
subprocess.run([sys.executable, str(ROOT / 'deliverables' / 'run_all_and_collect.py')], check=True)
